# %%
import pandas as pd 
import matplotlib as plt

# %% [markdown]
# ## Basic Data Cleaning

# %%
df_sales = pd.read_csv("dubai_valuation.csv")
df_sales
# Out:
#       instance_date  actual_worth row_status_code property_type_en  \
# 0        30-04-2005    9750000.00       COMPLETED             Land
# 1        16-03-2009   39883500.00       COMPLETED             Land
# 2        18-04-2004    4000000.00       COMPLETED             Land
# 3        22-03-2006    3000000.00       COMPLETED             Land
# 4            8/5/05   26208000.00       COMPLETED             Land
# ...             ...           ...             ...              ...
# 83386    15-05-2025    2144443.00       COMPLETED             Unit
# 83387    15-05-2025   11000000.00       COMPLETED             Land
# 83388    15-05-2025    2799996.00       COMPLETED             Land
# 83389    15-05-2025    2109414.72       COMPLETED             Unit
# 83390    15-05-2025    2103868.75       COMPLETED             Unit
#
#       property_sub_type_en                   area_name_en  actual_area
# 0               Commercial                      Al Baraha       696.77
# 1               Commercial                Al Barsha First      2470.20
# 2                Warehouse  Ras Al Khor Industrial Second      4455.35
# 3              Residential                Al Barsha Third      1393.55
# 4               Industrial                     Al Garhoud      4869.60
# ...                    ...                            ...          ...
# 83386                 Flat                     Al Merkadh       111.90
# 83387          Residential            Nad Al Shiba Fourth      2322.58
# 83388          Residential                         Mirdif       929.03
# 83389                 Flat                    Marsa Dubai        77.66
# 83390                 Flat                    Marsa Dubai        77.45
#
# [83391 rows x 7 columns]

# %%
#We are not dealing with Land only properties so remove all rows that have property type as land

df_sales = df_sales[df_sales["property_type_en"] != "Land"].reset_index(drop=True)
df_sales.index = range(1, len(df_sales) + 1)
df_sales
# Out:
#       instance_date  actual_worth row_status_code property_type_en  \
# 1        23-03-2010  2.200000e+08       COMPLETED         Building
# 2        19-04-2010  1.800000e+06       COMPLETED         Building
# 3           11/2/10  1.400000e+06       COMPLETED         Building
# 4        15-02-2010  8.500000e+05       COMPLETED             Unit
# 5        25-02-2010  7.500000e+05       COMPLETED             Unit
# ...             ...           ...             ...              ...
# 24579    15-05-2025  1.573635e+06       COMPLETED             Unit
# 24580    15-05-2025  1.539247e+06       COMPLETED             Unit
# 24581    15-05-2025  2.144443e+06       COMPLETED             Unit
# 24582    15-05-2025  2.109415e+06       COMPLETED             Unit
# 24583    15-05-2025  2.103869e+06       COMPLETED             Unit
#
#       property_sub_type_en        area_name_en  actual_area
# 1                 Building        Burj Khalifa     18481.57
# 2                    Villa      Wadi Al Safa 6       232.48
# 3                    Villa  Al Thanayah Fourth       172.31
# 4                     Flat         Marsa Dubai        66.33
# 5                     Flat         Marsa Dubai        85.38
# ...                    ...                 ...          ...
# 24579                 Flat    Al Khairan First        71.67
# 24580                 Flat    Al Thanyah Fifth       110.28
# 24581                 Flat          Al Merkadh       111.90
# 24582                 Flat         Marsa Dubai        77.66
# 24583                 Flat         Marsa Dubai        77.45
#
# [24583 rows x 7 columns]

# %%
#I want to see what are all the property types we have right now
types_properties = df_sales["property_type_en"].value_counts()
sub_types_properties = df_sales["property_sub_type_en"].value_counts()
print(f"Property_type : \n{types_properties}")
print(f"Subtype_property : \n {sub_types_properties}")
# Out:
# Property_type :
# property_type_en
# Unit        22267
# Building     2316
# Name: count, dtype: int64
# Subtype_property :
#  property_sub_type_en
# Flat                  16025
# Office                 4581
# Villa                  2262
# Shop                    965
# Hotel Apartment         354
# Hotel Rooms             259
# Building                 54
# Warehouse                39
# Workshop                 14
# Sized Partition          11
# Clinic                    7
# Hotel                     7
# Stacked Townhouses        3
# Gymnasium                 2
# Name: count, dtype: int64

# %%
'''
Since we are looking for properties for that correlate with office-commercial, normal living apartments, 
and luxuary apartments we can remove shop, warehoue, size partition, clinic, hotel,gymnasium ect.
'''
df_sales = df_sales[df_sales["property_sub_type_en"].isin(["Flat", "Office", "Villa", "Hotel Apartment", "Hotel Rooms", "Buildings"])].reset_index(drop = True)
#check if the other subcategories excluded
sub_types_properties = df_sales["property_sub_type_en"].value_counts()
print(f"Subtype_property : \n {sub_types_properties}")
# Out:
# Subtype_property :
#  property_sub_type_en
# Flat               16025
# Office              4581
# Villa               2262
# Hotel Apartment      354
# Hotel Rooms          259
# Name: count, dtype: int64

# %%
df_sales.index = range(1, len(df_sales) + 1)
df_sales
# Out:
#       instance_date  actual_worth row_status_code property_type_en  \
# 1        19-04-2010    1800000.00       COMPLETED         Building
# 2           11/2/10    1400000.00       COMPLETED         Building
# 3        15-02-2010     850000.00       COMPLETED             Unit
# 4        25-02-2010     750000.00       COMPLETED             Unit
# 5        25-03-2010    1350000.00       COMPLETED         Building
# ...             ...           ...             ...              ...
# 23477    15-05-2025    1573635.31       COMPLETED             Unit
# 23478    15-05-2025    1539247.12       COMPLETED             Unit
# 23479    15-05-2025    2144443.00       COMPLETED             Unit
# 23480    15-05-2025    2109414.72       COMPLETED             Unit
# 23481    15-05-2025    2103868.75       COMPLETED             Unit
#
#       property_sub_type_en        area_name_en  actual_area
# 1                    Villa      Wadi Al Safa 6       232.48
# 2                    Villa  Al Thanayah Fourth       172.31
# 3                     Flat         Marsa Dubai        66.33
# 4                     Flat         Marsa Dubai        85.38
# 5                    Villa  Al Thanayah Fourth       179.90
# ...                    ...                 ...          ...
# 23477                 Flat    Al Khairan First        71.67
# 23478                 Flat    Al Thanyah Fifth       110.28
# 23479                 Flat          Al Merkadh       111.90
# 23480                 Flat         Marsa Dubai        77.66
# 23481                 Flat         Marsa Dubai        77.45
#
# [23481 rows x 7 columns]

# %%
#Another major issue is the instance_data is not consistent so will convert all to mm/dd/yyyy format.
df_sales["instance_date"] = pd.to_datetime(df_sales["instance_date"],errors = "coerce",infer_datetime_format=True) #Letting pandas determine which time format it is in
df_sales["instance_date"] = df_sales["instance_date"].dt.strftime("%m/%d/%Y")
df_sales
# Out:
# /var/folders/pk/cfn_h0j14zb_9gy053hsz8d40000gn/T/ipykernel_83837/3975396150.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df["instance_date"] = pd.to_datetime(df["instance_date"],errors = "coerce",infer_datetime_format=True) #Letting pandas determine which time format it is in
# /var/folders/pk/cfn_h0j14zb_9gy053hsz8d40000gn/T/ipykernel_83837/3975396150.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["instance_date"] = pd.to_datetime(df["instance_date"],errors = "coerce",infer_datetime_format=True) #Letting pandas determine which time format it is in
#       instance_date  actual_worth row_status_code property_type_en  \
# 1        04/19/2010    1800000.00       COMPLETED         Building
# 2               NaN    1400000.00       COMPLETED         Building
# 3        02/15/2010     850000.00       COMPLETED             Unit
# 4        02/25/2010     750000.00       COMPLETED             Unit
# 5        03/25/2010    1350000.00       COMPLETED         Building
# ...             ...           ...             ...              ...
# 23477    05/15/2025    1573635.31       COMPLETED             Unit
# 23478    05/15/2025    1539247.12       COMPLETED             Unit
# 23479    05/15/2025    2144443.00       COMPLETED             Unit
# 23480    05/15/2025    2109414.72       COMPLETED             Unit
# 23481    05/15/2025    2103868.75       COMPLETED             Unit
#
#       property_sub_type_en        area_name_en  actual_area
# 1                    Villa      Wadi Al Safa 6       232.48
# 2                    Villa  Al Thanayah Fourth       172.31
# 3                     Flat         Marsa Dubai        66.33
# 4                     Flat         Marsa Dubai        85.38
# 5                    Villa  Al Thanayah Fourth       179.90
# ...                    ...                 ...          ...
# 23477                 Flat    Al Khairan First        71.67
# 23478                 Flat    Al Thanyah Fifth       110.28
# 23479                 Flat          Al Merkadh       111.90
# 23480                 Flat         Marsa Dubai        77.66
# 23481                 Flat         Marsa Dubai        77.45
#
# [23481 rows x 7 columns]

# %%
#now lets look into status_code to see what work would be incomplete
df_sales_status_count = df_sales["row_status_code"].value_counts()
df_sales_status_count
# Out:
# row_status_code
# COMPLETED    23463
# COMMITTED       10
# ENTERED          8
# Name: count, dtype: int64

# %%
#We can see that most of the data points that are not corresponding to completed status are projects 
#initiated in recent years with a few null value (16.67%)
df_status_not_completed = df_sales[df_sales["row_status_code"].isin(["COMMITTED","ENTERED"])].reset_index(drop=True)
df_sales_status_not_completed.index = range(1, len(df_status_not_completed) + 1)
df_status_not_completed
# Out:
#    instance_date  actual_worth row_status_code property_type_en  \
# 1            NaN      908473.0         ENTERED             Unit
# 2            NaN        2669.0         ENTERED             Unit
# 3     11/20/2023     3650000.0         ENTERED             Unit
# 4     07/22/2024     1200000.0         ENTERED             Unit
# 5     09/30/2024     2500000.0       COMMITTED             Unit
# 6     12/26/2024    55000000.0       COMMITTED         Building
# 7     11/19/2023     2500000.0       COMMITTED             Unit
# 8     07/15/2024     3000000.0         ENTERED             Unit
# 9     12/22/2023     2150000.0         ENTERED         Building
# 10    04/23/2025          35.0         ENTERED             Unit
# 11    02/25/2025     1276060.0         ENTERED             Unit
# 12    05/19/2025     2700000.0       COMMITTED             Unit
# 13    05/21/2025     3556247.0       COMMITTED             Unit
# 14    05/21/2025     5366369.0       COMMITTED             Unit
# 15    05/21/2025     6835007.0       COMMITTED             Unit
# 16    05/21/2025    11571020.0       COMMITTED             Unit
# 17           NaN     3500000.0       COMMITTED         Building
# 18    05/14/2025     4348626.0       COMMITTED             Unit
#
#    property_sub_type_en            area_name_en  actual_area
# 1                Office            Business Bay       105.50
# 2                Office        Al Thanyah Fifth       248.05
# 3                  Flat         Al Hebiah First       488.79
# 4                  Flat            Business Bay        77.03
# 5                  Flat             Marsa Dubai       153.59
# 6                 Villa           World Islands      1699.43
# 7                  Flat          Zaabeel Second       111.28
# 8           Hotel Rooms           World Islands       144.09
# 9                 Villa      Al Thanayah Fourth       207.08
# 10                 Flat  Al Barsha South Fourth        35.77
# 11                 Flat             Marsa Dubai        47.42
# 12                 Flat            Burj Khalifa        76.28
# 13                 Flat      Nad Al Shiba First       140.59
# 14                 Flat      Nad Al Shiba First       212.15
# 15                 Flat      Nad Al Shiba First       270.21
# 16                 Flat      Nad Al Shiba First       457.44
# 17                Villa          Wadi Al Safa 7       493.87
# 18                 Flat          Jumeirah First       149.63
